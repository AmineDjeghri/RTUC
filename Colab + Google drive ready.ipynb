# %%
# connect to google drive and move to the selected directory
from google.colab import drive
drive.mount('/content/gdrive')
# %cd "/content/gdrive/My Drive" #select the current working derectory
# !pwd 
# !ls

# %%
#REQUIRED: ACTIVATE the gpu: (In the menu tabs, "Runtime" => "Change runtime type and select gpu) 
import torch
print("avaible GPUs:",torch.cuda.device_count())
print("GPU name:",torch.cuda.get_device_name())
# Out:
# avaible GPUs: 1
# GPU name: Tesla T4

# %%
#here install what you want with !pip install  exemple :
# !pip install transformers

# %%
#If you want to install permanently a library, and also use colab without a key authorization everytime
# https://stackoverflow.com/questions/55253498/how-do-i-install-a-library-permanently-in-colab
